# %%
from langchain.llms import OpenAI
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# openAI token
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('team_token')

# %%
link = os.getenv('dsa_2214')

# %%
model = OpenAI()
learning_concept = model(f'Please identify learning concept maps from this textbook on Data Structures and Algorithms: {link}')

# %%
learning_concept.split('\n')
# Out:
# ['',
#  '',
#  '1. Introduction to Data Structures and Algorithms',
#  '2. Fundamental Concepts of Algorithm Analysis',
#  '3. Arrays and Linked Lists',
#  '4. Stacks and Queues',
#  '5. Trees',
#  '6. Hash Tables',
#  '7. Priority Queues and Heaps',
#  '8. Sorting Algorithms',
#  '9. Searching Algorithms',
#  '10. Graphs and Graph Traversals',
#  '11. Advanced Data Structures',
#  '12. Algorithm Design Techniques',
#  '13. Greedy Algorithms',
#  '14. Dynamic Programming',
#  '15. Divide and Conquer',
#  '16. Backtracking',
#  '17. Complexity Theory and NP-Completeness',
#  '18. Advanced Topics in Data Structures and Algorithms',
#  '19. Implementation and Performance Analysis',
#  '20. Conclusion and Future Directions']

# %%
learning_concept[3:len(learning_concept)-1].split('\n')
# Out:
# ['. Introduction to Data Structures and Algorithms',
#  '2. Fundamental Concepts of Algorithm Analysis',
#  '3. Arrays and Linked Lists',
#  '4. Stacks and Queues',
#  '5. Trees',
#  '6. Hash Tables',
#  '7. Priority Queues and Heaps',
#  '8. Sorting Algorithms',
#  '9. Searching Algorithms',
#  '10. Graphs and Graph Traversals',
#  '11. Advanced Data Structures',
#  '12. Algorithm Design Techniques',
#  '13. Greedy Algorithms',
#  '14. Dynamic Programming',
#  '15. Divide and Conquer',
#  '16. Backtracking',
#  '17. Complexity Theory and NP-Completeness',
#  '18. Advanced Topics in Data Structures and Algorithms',
#  '19. Implementation and Performance Analysis',
#  '20. Conclusion and Future Direction']
