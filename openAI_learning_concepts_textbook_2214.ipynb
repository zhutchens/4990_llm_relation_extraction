# %%
from langchain.llms import OpenAI
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader

# %%
# openAI token
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('team_token')

# %%
link = os.getenv('dsa_2214')

# %%
model = OpenAI()
learning_concept = model(f'Please identify learning concept maps from this textbook on Data Structures and Algorithms: {link}')
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
learning_concept.split('\n')
# Out:
# ['',
#  '',
#  '1. Basic Data Structures: Introduces the foundational concepts of data structures, such as arrays, lists, stacks, queues, and trees, and their operations and applications.',
#  '',
#  '2. Advanced Data Structures: Expands upon basic data structures and covers topics such as hash tables, heaps, graphs, and advanced tree structures.',
#  '',
#  '3. Algorithm Analysis: Explains the importance of analyzing algorithms and their time and space complexity, and how it relates to the efficiency and performance of a program.',
#  '',
#  '4. Searching and Sorting: Discusses different search and sort algorithms, their implementations, and their performance in various scenarios.',
#  '',
#  '5. Recursion: Covers the concept of recursion and its applications in solving problems, as well as the implementation of recursive algorithms.',
#  '',
#  '6. Trees and Tree Algorithms: Focuses on the various types of trees and their properties, as well as algorithms for traversing, inserting, and deleting nodes in a tree.',
#  '',
#  '7. Graph Algorithms: Introduces graph data structures and their applications, and covers various graph algorithms such as shortest path, minimum spanning tree, and topological sorting.',
#  '',
#  '8. Memory Management: Discusses the role of memory in data structures and algorithms, and techniques for managing memory efficiently.',
#  '',
#  '9. Object-Oriented Design: Explores the use of object']

# %%
learning_concept[3:len(learning_concept)-1].split('\n')
# Out:
# ['. Basic Data Structures: Introduces the foundational concepts of data structures, such as arrays, lists, stacks, queues, and trees, and their operations and applications.',
#  '',
#  '2. Advanced Data Structures: Expands upon basic data structures and covers topics such as hash tables, heaps, graphs, and advanced tree structures.',
#  '',
#  '3. Algorithm Analysis: Explains the importance of analyzing algorithms and their time and space complexity, and how it relates to the efficiency and performance of a program.',
#  '',
#  '4. Searching and Sorting: Discusses different search and sort algorithms, their implementations, and their performance in various scenarios.',
#  '',
#  '5. Recursion: Covers the concept of recursion and its applications in solving problems, as well as the implementation of recursive algorithms.',
#  '',
#  '6. Trees and Tree Algorithms: Focuses on the various types of trees and their properties, as well as algorithms for traversing, inserting, and deleting nodes in a tree.',
#  '',
#  '7. Graph Algorithms: Introduces graph data structures and their applications, and covers various graph algorithms such as shortest path, minimum spanning tree, and topological sorting.',
#  '',
#  '8. Memory Management: Discusses the role of memory in data structures and algorithms, and techniques for managing memory efficiently.',
#  '',
#  '9. Object-Oriented Design: Explores the use of objec']
