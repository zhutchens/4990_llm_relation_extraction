# %%
from relation_algorithms.relation_extraction_functions import LLM_Relation_Extractor
from os import getenv
from dotenv import load_dotenv
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
load_dotenv()
hadoop_tb = getenv('hadoop')
relation_extractor = LLM_Relation_Extractor(textbook_link = hadoop_tb)

# %%
main_topics = relation_extractor.identify_main_topics()
main_topics
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ['1. Introduction to Hadoop and big data',
#  '2. Hadoop architecture and components',
#  '3. HDFS (Hadoop Distributed File System)',
#  '4. MapReduce programming model',
#  '5. YARN (Yet Another Resource Negotiator)',
#  '6. Hadoop cluster setup and configuration',
#  '7. Hadoop data ingestion and processing',
#  '8. Hadoop data storage and retrieval',
#  '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#  '10. Hadoop security and monitoring.']

# %%
main_concept_graph = relation_extractor.association_identification(concept_list = main_topics)
main_concept_graph
# Out:
# {'1. Introduction to Hadoop and big data': ['2. Hadoop architecture and components',
#   '3. HDFS (Hadoop Distributed File System)',
#   '4. MapReduce programming model',
#   '5. YARN (Yet Another Resource Negotiator)',
#   '6. Hadoop cluster setup and configuration',
#   '7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '2. Hadoop architecture and components': ['3. HDFS (Hadoop Distributed File System)',
#   '4. MapReduce programming model',
#   '5. YARN (Yet Another Resource Negotiator)',
#   '6. Hadoop cluster setup and configuration',
#   '7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '3. HDFS (Hadoop Distributed File System)': ['4. MapReduce programming model',
#   '5. YARN (Yet Another Resource Negotiator)',
#   '6. Hadoop cluster setup and configuration',
#   '7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '4. MapReduce programming model': ['5. YARN (Yet Another Resource Negotiator)',
#   '6. Hadoop cluster setup and configuration',
#   '7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '5. YARN (Yet Another Resource Negotiator)': ['6. Hadoop cluster setup and configuration',
#   '7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '6. Hadoop cluster setup and configuration': ['7. Hadoop data ingestion and processing',
#   '8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '7. Hadoop data ingestion and processing': ['8. Hadoop data storage and retrieval',
#   '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '8. Hadoop data storage and retrieval': ['9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)',
#   '10. Hadoop security and monitoring.'],
#  '9. Hadoop ecosystem and related technologies (Hive, Pig, Spark, etc.)': ['10. Hadoop security and monitoring.'],
#  '10. Hadoop security and monitoring.': []}

# %%
dependencies = relation_extractor.dependency_relation_extraction(keys = main_topics)

# %%
relation_extractor.identify_chapters()
# Out:
# ['1. Introduction',
#  '2. Hadoop: A Short History',
#  '3. HDFS: The Hadoop Distributed File System',
#  '4. MapReduce',
#  '5. The Hadoop Ecosystem',
#  '6. Planning Your Hadoop Cluster',
#  '7. Hadoop Installation and Initial Configuration',
#  '8. HDFS Architecture',
#  '9. HDFS Operations',
#  '10. MapReduce Architecture',
#  '11. Developing a MapReduce Application',
#  '12. Advanced MapReduce Features',
#  '13. Hadoop I/O',
#  '14. Monitoring and Debugging',
#  '15. Hadoop Security',
#  '16. Hadoop Streaming',
#  '17. Hive',
#  '18. Pig',
#  '19. HBase',
#  '20. ZooKeeper',
#  '21. Sqoop',
#  '22. Flume',
#  '23. Oozie',
#  '24. Hue',
#  '25. Avro',
#  '26. Parquet',
#  '27. Crunch',
#  '28. Cascading',
#  '29. Spark',
#  '30. Hadoop on Windows',
#  '31. Hadoop on Amazon Web Services',
#  '32. Hadoop on Microsoft Azure',
#  '33. Hadoop on Google Cloud Platform',
#  '34. Hadoop on Docker',
#  '35. Hadoop Operations and Cluster Management',
#  '36. Troubleshooting',
#  '37. Case Studies']

# %%
relation_extractor.print_flat_graph(learning_concept_graph = main_concept_graph)

# %%
relation_extractor.print_flat_graph(learning_concept_graph = dependencies)
