# %%
from relation_algorithms.relation_extraction_functions import LLM_Relation_Extractor

link = "https://webpages.charlotte.edu/qcheng1/etextbook/ITCS6114_2009_Introduction_to_Algorithms_Third_Ed_By_ThomasHCormen_good.pdf"
extractor = LLM_Relation_Extractor(link = link)

# %%
chapters = ['The Role of Algorithms in Computing',
            'Getting Started',
            'Growth of Algoritmhs',
            'Divide-and-Conquer',
            'Probabilistic Analysis and Randomized Algorithms',
            'Heapsort',
            'Quicksort',
            'Sorting in Linear Time',
            'Medians and Order Statistics',
            'Elementary Data Structures',
            'Hash Tables',
            'Binary Search Trees',
            'Red-Black Trees',
            'Augmenting Data Structures',
            'Dynamic Programming',
            'Greedy Algorithms',
            'Amortized Analysis',
            'B-Trees',
            'Fibonacci Heaps',
            'van Emde Boas Trees',
            'Data Structure for Disjoint Sets',
            'Elementary Graph Algoritmhs',
            'Minimum Spanning Trees',
            'Single-Source Shortest Paths',
            'All-Pairs Shortest Paths',
            'Maximum Flow',
            'Multithreaded Algoritmhs',
            'Matrix Operations',
            'Linear Programming',
            'Polynomials and the FFT',
            'Number-Theoretic Algorithms',
            'String Matching',
            'Computational Geometry',
            'NP-Completeness',
            'Approximation Algorithms']

# %%
learning_outcomes = extractor.identify_learning_outcomes(chapters = chapters)
learning_outcomes
# Out:
# ['\n1. Understanding the basic concepts of algorithms and their role in computing.\n2. Identifying different types of algorithms and their applications.\n3. Analyzing the efficiency and correctness of algorithms.\n4. Applying algorithm design techniques to solve problems.\n5. Understanding the importance of data structures in algorithm design.\n6. Recognizing the impact of algorithms on performance and scalability.\n7. Evaluating the trade-offs between different algorithmic approaches.\n8. Understanding the limitations of algorithms and their potential for improvement.\n9. Applying algorithmic thinking to real-world problems.\n10. Identifying ethical considerations in the use of algorithms in computing.',
#  '\nThe main learning outcomes of Chapter 1, Getting Started, are:\n\n1. Understand the basic concepts and terminology used in algorithm analysis, including inputs, outputs, and problem instances.\n2. Identify different types of algorithms and their characteristics, such as brute-force, divide-and-conquer, and greedy algorithms.\n3. Learn about algorithmic complexity and the importance of analyzing the efficiency of algorithms.\n4. Understand the role of data structures in algorithm design and how they can impact the efficiency of algorithms.\n5. Learn how to measure and compare the performance of algorithms using big-O notation.\n6. Understand the concept of recursion and its role in algorithm design.\n7. Learn about the basics of designing and implementing algorithms, including pseudocode, loop invariants, and correctness proofs.\n8. Understand the basics of analyzing algorithms using asymptotic notation.\n9. Learn about the importance of problem-solving skills and the role of algorithms in problem solving.\n10. Explore the impact of technology and the internet on algorithm design and analysis.',
#  '\n1. Understand the fundamental concepts and techniques used in algorithm analysis and design.\n2. Recognize the importance of efficiency in algorithm design and implementation.\n3. Explain the basics of growth rates and asymptotic notation.\n4. Analyze the worst-case, best-case, and average-case running time of algorithms.\n5. Compare and contrast different algorithm design paradigms, such as divide and conquer, greedy, and dynamic programming.\n6. Identify and apply appropriate data structures for efficient algorithm implementation.\n7. Evaluate the space complexity of algorithms and data structures.\n8. Understand the trade-offs between time and space complexity in algorithm design.\n9. Apply algorithmic techniques, such as sorting and searching, to solve real-world problems.\n10. Use recursion to solve complex algorithmic problems.\n11. Understand the limitations of algorithms and the concept of NP-completeness.\n12. Apply optimization techniques to improve the efficiency of algorithms.\n13. Analyze and compare the performance of different algorithms for the same problem.\n14. Understand the role of randomness in algorithm design and analysis.\n15. Apply algorithmic thinking to solve problems in various domains. ',
#  '\n1. Understand the concept of divide-and-conquer and its application in solving complex problems.\n2. Identify the three basic steps of divide-and-conquer: divide, conquer, and combine.\n3. Analyze the time complexity of divide-and-conquer algorithms using recurrence relations.\n4. Apply the Master Theorem to determine the time complexity of divide-and-conquer algorithms.\n5. Identify and explain the design strategies for divide-and-conquer algorithms, such as recursion and tail recursion.\n6. Understand the trade-offs involved in choosing the base case and partitioning strategy for divide-and-conquer algorithms.\n7. Apply divide-and-conquer techniques to solve various problems, such as sorting, searching, and matrix multiplication.\n8. Understand the limitations and potential pitfalls of divide-and-conquer algorithms.\n9. Recognize and explain the similarities and differences between divide-and-conquer and dynamic programming.\n10. Apply divide-and-conquer to solve real-world problems and analyze the efficiency of the solution.',
#  '\nThe main learning outcomes for this chapter are:\n\n1. Understand the basics of probability theory and its applications in algorithm analysis.\n2. Learn how to analyze the expected running time of randomized algorithms.\n3. Understand the concept of randomized algorithms and their advantages over deterministic algorithms.\n4. Learn how to use probabilistic techniques to design efficient algorithms.\n5. Understand the trade-offs between randomized and deterministic algorithms.\n6. Learn about important randomized algorithms, such as randomized quicksort and randomized primality testing.\n7. Understand the concept of expected case analysis and its relevance in randomized algorithms.\n8. Learn how to analyze the probability of error in randomized algorithms.\n9. Understand the concept of average-case analysis and its applications in randomized algorithms.\n10. Learn about the limitations of randomized algorithms and when they should be used.',
#  '\n1. Understanding the basic principles and implementation of Heapsort algorithm.\n2. Ability to analyze the time and space complexity of Heapsort.\n3. Familiarity with the data structure of a heap and its operations.\n4. Understanding the role of Heapsort in sorting algorithms and its advantages and disadvantages.\n5. Ability to apply Heapsort to solve real-world problems and optimization.\n6. Familiarity with the concept of heap property and its relationship with the Heapsort algorithm.\n7. Understanding the importance of heap construction and heapify in the Heapsort algorithm.\n8. Ability to implement Heapsort in various programming languages.\n9. Understanding the use of Heapsort in priority queues and its applications.\n10. Familiarity with the variations of Heapsort, such as bottom-up Heapsort and k-way merge Heapsort.',
#  '\n1. Understand the concept of divide and conquer in algorithm design.\n2. Be able to implement the Quicksort algorithm.\n3. Understand the time complexity and space complexity of Quicksort.\n4. Know how to choose a good pivot element in Quicksort.\n5. Understand the advantages and disadvantages of Quicksort compared to other sorting algorithms.\n6. Be able to analyze the worst-case, best-case, and average-case scenarios for Quicksort.\n7. Understand the partitioning process and its role in Quicksort.\n8. Be able to apply the Hoare partition scheme to Quicksort.\n9. Understand the concept of tail recursion and its use in Quicksort.\n10. Be able to explain how Quicksort can be used for sorting in parallel.',
#  '\n1. Understand the concept of sorting and its importance in computer science.\n2. Describe the characteristics and performance of different sorting algorithms.\n3. Analyze the time and space complexity of sorting algorithms.\n4. Implement efficient sorting algorithms, including insertion sort, selection sort, and merge sort.\n5. Understand the difference between in-place and stable sorting algorithms.\n6. Apply the divide-and-conquer approach to design efficient sorting algorithms.\n7. Recognize the limitations of comparison-based sorting algorithms.\n8. Understand the concept of randomized algorithms and their use in sorting.\n9. Evaluate the practical applications of sorting algorithms in real-world scenarios.\n10. Compare and contrast different sorting algorithms to choose the most appropriate one for a given problem.',
#  '\n1. Understand the concept of medians and how to calculate them.\n2. Understand the role of medians in order statistics.\n3. Be able to use medians to find the kth smallest element in a set of data.\n4. Understand the relationship between medians and partitioning algorithms.\n5. Be able to implement efficient algorithms for finding medians and order statistics.\n6. Understand the applications of medians and order statistics in sorting and searching algorithms.\n7. Be able to analyze the time and space complexity of algorithms for medians and order statistics.\n8. Understand the limitations and trade-offs of different approaches for finding medians and order statistics.',
#  '\n1. Understand the concept of data structures and their importance in problem-solving and algorithm design.\n2. Identify and differentiate between different types of data structures, including arrays, linked lists, stacks, queues, trees, and graphs.\n3. Understand the basic operations and properties of each data structure.\n4. Analyze the time and space complexity of operations on data structures.\n5. Understand the trade-offs involved in choosing a data structure for a specific problem.\n6. Implement basic data structures using appropriate programming languages.\n7. Understand the concept of abstract data types (ADTs) and their relationship to data structures.\n8. Apply data structures to solve real-world problems and algorithms.\n9. Understand the concept of recursion and how it can be applied to data structures.\n10. Understand the concept of sorting and its implementation using data structures.\n11. Understand the concept of searching and its implementation using data structures.',
#  '1. Understand the concept and purpose of hash tables in data organization and retrieval.\n2. Describe the key components and operations of a hash table, including hashing function and collision resolution.\n3. Analyze the time and space complexity of various hash table operations.\n4. Compare and contrast different types of collision resolution techniques.\n5. Implement and utilize hash tables in solving real-world problems.\n6. Explain the trade-offs involved in choosing a particular hashing function and collision resolution strategy.\n7. Understand the concepts of load factor and how it affects the efficiency of a hash table.\n8. Apply knowledge of hash tables to optimize performance and memory usage in applications.\n9. Recognize potential security vulnerabilities associated with hash tables and ways to mitigate them.\n10. Evaluate the strengths and limitations of hash tables in different scenarios.\n',
#  '\n1. Understand the concept of a binary search tree and the properties that make it efficient for searching and inserting data.\n2. Be able to implement basic operations on a binary search tree, such as search, insert, and delete.\n3. Understand the time complexity of operations on a binary search tree and how it compares to other data structures.\n4. Recognize the importance of maintaining the binary search tree properties and be able to perform rotations to maintain balance.\n5. Understand the differences between a binary search tree and other types of binary trees, such as balanced and unbalanced trees.\n6. Know how to traverse a binary search tree in different orders, such as in-order, pre-order, and post-order.\n7. Be able to identify and handle different cases when inserting or deleting nodes in a binary search tree.\n8. Understand the concept of self-balancing binary search trees and their advantages in maintaining efficiency.\n9. Recognize the limitations of binary search trees, such as the worst-case scenario for search.\n10. Understand the applications of binary search trees in real-world problems, such as in databases and sorting algorithms.',
#  '\n1. Understand the properties and characteristics of Red-Black Trees.\n2. Recognize the importance of balancing in maintaining a balanced tree structure.\n3. Understand the rules for inserting and deleting nodes in a Red-Black Tree.\n4. Be able to perform rotations and recoloring to maintain the balance of a Red-Black Tree.\n5. Understand the complexity of operations on Red-Black Trees and how they differ from other types of balanced trees.\n6. Understand the relationship between Red-Black Trees and other types of balanced trees.\n7. Understand the advantages and disadvantages of using Red-Black Trees over other types of balanced trees.\n8. Be able to analyze the time and space complexity of algorithms on Red-Black Trees.\n9. Recognize the applications of Red-Black Trees in data structures and algorithms.\n10. Be able to implement a Red-Black Tree data structure in a programming language.',
#  '\n1. Understand the concept of augmenting data structures and its importance in algorithm design.\n2. Learn how to implement augmentations to data structures in order to improve their efficiency and performance.\n3. Understand the trade-offs involved in augmenting data structures and how to choose the appropriate augmentation for a specific problem.\n4. Gain knowledge on how to analyze the time and space complexity of augmented data structures.\n5. Learn various techniques for augmenting different types of data structures, such as arrays, linked lists, trees, and heaps.\n6. Understand the applications of augmented data structures in solving real-world problems and their impact on algorithm design.\n7. Learn about self-balancing data structures and their role in maintaining efficient data structures.\n8. Understand the concept of amortized analysis and its application in analyzing the performance of augmented data structures.\n9. Develop the ability to design and implement efficient algorithms using augmented data structures.',
#  '\n1. Understand the concept of dynamic programming and its applications in solving optimization problems.\n2. Identify and apply the basic elements of a dynamic programming solution, including optimal substructure and overlapping subproblems.\n3. Explain the importance of memoization in dynamic programming and its role in improving time complexity.\n4. Demonstrate the ability to design and analyze dynamic programming algorithms.\n5. Solve problems using dynamic programming techniques, including the knapsack problem, matrix chain multiplication, and longest common subsequence.',
#  '\n1. Understand the concept of a greedy algorithm and its applications.\n2. Describe the basic steps of a greedy algorithm.\n3. Identify and analyze the advantages and disadvantages of using a greedy approach.\n4. Apply greedy algorithms to solve optimization problems.\n5. Compare and contrast greedy algorithms with other types of algorithms.\n6. Use mathematical and algorithmic techniques to prove the correctness and optimality of greedy algorithms.\n7. Analyze the time and space complexities of greedy algorithms.\n8. Recognize when a greedy algorithm is appropriate for a given problem.\n9. Understand the concept of a greedy choice property and its role in greedy algorithms.\n10. Apply greedy algorithms to solve real-world problems.',
#  '\n1. Understand the concept of amortized analysis and its importance in analyzing the performance of algorithms.\n2. Learn the basics of amortized analysis, including the amortized cost and potential method.\n3. Understand the difference between worst-case, average-case, and amortized analysis.\n4. Learn how to use amortized analysis to analyze the time complexity of data structures such as stacks, queues, and dynamic arrays.\n5. Understand the concept of aggregate analysis and its application in amortized analysis.\n6. Learn how to apply amortized analysis to determine the time complexity of algorithms with repeated operations.\n7. Understand the relationship between amortized analysis and the concept of potential energy.\n8. Learn the limitations of amortized analysis and when it may not accurately reflect the true performance of an algorithm.\n9. Understand the difference between amortized analysis and average-case analysis.\n10. Learn how to use amortized analysis to compare and choose between different algorithms with similar time complexities.',
#  '\nThe main learning outcomes from the chapter on B-trees are:\n\n1. Understanding the structure and properties of B-trees, including the concept of order and the use of nodes and pointers.\n2. Knowing how to insert and delete elements in a B-tree, and how these operations maintain the balance and order of the tree.\n3. Understanding the benefits of using B-trees for storing and retrieving data, particularly in comparison to other data structures such as binary search trees.\n4. Knowing how to perform search operations on a B-tree and how the structure of the tree contributes to efficient search.\n5. Understanding the concept of external B-trees and their use in external data storage.\n6. Knowing how to analyze the time complexity of operations on B-trees, including insertion, deletion, and search.\n7. Understanding the various applications of B-trees, such as in databases and file systems.\n8. Being able to design and implement B-trees for specific applications.\n9. Understanding the limitations and potential issues of B-trees, such as the need for rebalancing and the impact of disk access times.\n10. Being able to compare and contrast B-trees with other data structures and determine the most appropriate one for a given problem.',
#  "\nAfter studying this chapter on Fibonacci Heaps, students should be able to:\n\n1. Explain the basic structure and properties of a Fibonacci Heap\n2. Implement the operations of a Fibonacci Heap, including Insert, Extract-Min, Decrease-Key, and Merge\n3. Analyze the time complexity of these operations and compare them to other heap data structures\n4. Understand the concept of amortized analysis and its application to Fibonacci Heaps\n5. Identify the advantages and disadvantages of using a Fibonacci Heap in comparison to other data structures\n6. Apply Fibonacci Heaps to solve various problems and algorithms, such as Dijkstra's algorithm and Prim's algorithm.",
#  '\n1. Understand the structure and properties of van Emde Boas Trees\n2. Learn the implementation of van Emde Boas Trees for efficient operations on a set of integers\n3. Analyze the time and space complexity of operations on van Emde Boas Trees\n4. Compare and contrast van Emde Boas Trees with other data structures such as binary search trees and hash tables\n5. Apply van Emde Boas Trees to solve problems related to sets of integers and their operations.',
#  "\n1. Understand the concept of disjoint sets and their applications in data structure.\n2. Familiarize with the operations of creating, merging, and finding the representative element of a set.\n3. Learn how to implement and analyze the performance of different data structures for disjoint sets, such as linked lists, trees, and arrays.\n4. Understand the concept of path compression and union by rank for improving the efficiency of operations on disjoint sets.\n5. Learn about the application of disjoint sets in various algorithms, such as Kruskal's minimum spanning tree algorithm and Tarjan's strongly connected components algorithm.\n6. Understand the time complexity of operations on disjoint sets and how to analyze them using the amortized analysis.\n7. Learn about the limitations and potential trade-offs of different data structures for disjoint sets.\n8. Explore the use of disjoint sets in solving real-world problems, such as image segmentation and social networks.\n9. Understand the importance of efficient data structures for disjoint sets and their impact on the overall performance of algorithms.",
#  "\n1. Understand the basic concepts of graph theory and the terminology associated with it.\n2. Be able to represent graphs using various data structures such as adjacency matrices and adjacency lists.\n3. Understand the difference between directed and undirected graphs and the implications for graph algorithms.\n4. Be able to traverse a graph using breadth-first search and depth-first search.\n5. Understand the concept of a minimum spanning tree and be able to find one using Kruskal's and Prim's algorithms.\n6. Be able to find the shortest path between two vertices in a graph using Dijkstra's algorithm.\n7. Understand the basics of topological sorting and be able to perform it on a directed acyclic graph.\n8. Understand the concept of strong connectivity and be able to find strongly connected components in a directed graph.\n9. Be able to recognize and handle basic graph problems such as cycle detection and connectivity testing.\n10. Understand the limitations of graph algorithms and when they may not be applicable.",
#  "\n1. Understand the concept of minimum spanning trees and their applications in various fields.\n2. Identify and implement algorithms for finding minimum spanning trees, such as Prim's and Kruskal's algorithms.\n3. Analyze the time and space complexity of different minimum spanning tree algorithms.\n4. Understand the key properties of minimum spanning trees, such as cut property and cycle property.\n5. Apply minimum spanning tree algorithms to solve real-world problems, such as network design and clustering.\n6. Explore variations of minimum spanning trees, such as weighted and directed graphs.\n7. Understand the trade-offs between different minimum spanning tree algorithms.\n8. Compare and contrast minimum spanning tree algorithms with other graph algorithms.\n9. Understand the role of minimum spanning trees in optimization and approximation algorithms.\n10. Apply knowledge of minimum spanning trees to design efficient algorithms for specific problems.",
#  "\n1. Understand the concept of single-source shortest paths and its applications in real-world problems.\n2. Describe and analyze the Dijkstra's algorithm for finding single-source shortest paths in a weighted, directed graph.\n3. Understand the importance of using a priority queue in Dijkstra's algorithm to improve its efficiency.\n4. Explain the Bellman-Ford algorithm for finding single-source shortest paths in a weighted, directed graph with negative edge weights.\n5. Compare and contrast the Dijkstra's algorithm and the Bellman-Ford algorithm, including their time and space complexity.\n6. Understand the concept of a shortest-path tree and its use in finding single-source shortest paths.\n7. Describe how to use the Floyd-Warshall algorithm to find all-pairs shortest paths in a weighted, directed graph.\n8. Understand the concept of dynamic programming and its role in the Floyd-Warshall algorithm.\n9. Analyze the time and space complexity of the Floyd-Warshall algorithm.\n10. Apply the concepts learned to solve real-world problems involving finding shortest paths in a graph.",
#  "\n1. Understand the concept of shortest paths in a directed weighted graph.\n2. Describe the Floyd-Warshall algorithm for finding all-pairs shortest paths.\n3. Demonstrate the implementation of the Floyd-Warshall algorithm using dynamic programming.\n4. Analyze the time and space complexity of the Floyd-Warshall algorithm.\n5. Apply the Floyd-Warshall algorithm to solve real-world problems such as network routing and traffic optimization.\n6. Compare and contrast the Floyd-Warshall algorithm with other shortest path algorithms such as Dijkstra's algorithm and Bellman-Ford algorithm.\n7. Discuss the limitations and potential applications of the Floyd-Warshall algorithm.",
#  '\nThe main learning outcomes of this chapter on Maximum Flow include:\n1. Understanding the concept of flow networks and how they can be represented using directed graphs.\n2. Familiarity with the Ford-Fulkerson algorithm for finding the maximum flow in a network.\n3. Knowledge of different augmenting paths and how they can be used to improve the flow in a network.\n4. Ability to identify and handle special cases, such as multiple sources or sinks, in a flow network.\n5. Understanding the concept of minimum cut and its relationship to maximum flow.\n6. Knowledge of the Edmonds-Karp algorithm and its advantages over the Ford-Fulkerson algorithm.\n7. Familiarity with the push-relabel algorithm and its use of preflow and excess flow.\n8. Ability to analyze the time complexity of different maximum flow algorithms.\n9. Understanding of the concept of duality in flow networks and its application in solving maximum flow problems.\n10. Knowledge of different applications of maximum flow, such as in network flow optimization and bipartite matching.',
#  '\n1. Understand the concept of multithreading and its benefits in algorithm design and performance.\n2. Learn how to design and implement multithreaded algorithms for various computing problems.\n3. Understand the different approaches to multithreading, including shared-memory and message-passing models.\n4. Learn techniques for synchronization and communication between multiple threads in a multithreaded algorithm.\n5. Understand the potential issues and challenges in designing and debugging multithreaded algorithms.\n6. Analyze the efficiency and scalability of multithreaded algorithms in different scenarios.\n7. Gain practical experience in implementing and testing multithreaded algorithms.\n8. Understand the trade-offs between parallelism and overhead in multithreaded algorithms.\n9. Explore real-world applications of multithreaded algorithms in different domains.\n10. Develop critical thinking skills for selecting appropriate multithreading strategies for different problems.',
#  '\n1. Understanding the basic principles and properties of matrices\n2. Performing matrix operations such as addition, subtraction, multiplication, and division\n3. Solving systems of linear equations using matrices\n4. Identifying and manipulating matrix inverses and determinants\n5. Understanding the concept of rank and its use in matrix operations\n6. Applying matrix operations to solve real-world problems and applications\n7. Understanding the efficiency and complexity of matrix operations\n8. Implementing matrix operations in computer algorithms and programs',
#  '\n1. Understand the concept of linear programming and its applications in solving optimization problems.\n2. Identify the components of a linear programming problem, including the objective function, constraints, and decision variables.\n3. Apply the simplex method to solve a linear programming problem.\n4. Analyze the feasibility and optimality of a solution to a linear programming problem.\n5. Understand the duality theory and its application in solving linear programming problems.\n6. Recognize special cases of linear programming, such as integer programming and network flow problems.\n7. Use sensitivity analysis to determine the impact of changes in problem parameters on the optimal solution.\n8. Apply linear programming to real-world problems, such as resource allocation and production planning.',
#  '\n1. Understand the concept of polynomials and their properties.\n2. Apply polynomial operations, such as addition, subtraction, multiplication, and division.\n3. Use synthetic division to find roots of a polynomial.\n4. Understand the basics of the Fast Fourier Transform (FFT) and its applications in polynomial multiplication.\n5. Analyze the time complexity of the FFT algorithm and compare it to traditional polynomial multiplication methods.\n6. Apply the FFT algorithm to solve problems such as polynomial interpolation and convolution.\n7. Understand the limitations and assumptions of using FFT for polynomial multiplication.\n8. Analyze and implement efficient algorithms for polynomial multiplication, such as the Karatsuba-Ofman algorithm.',
#  "\n1. Understand the fundamental concepts of number theory, including divisibility, prime numbers, and modular arithmetic.\n2. Learn the Euclidean algorithm for finding the greatest common divisor of two integers.\n3. Understand the extended Euclidean algorithm for finding the coefficients of Bézout's identity and using it for solving linear diophantine equations.\n4. Learn the Chinese remainder theorem and its applications in solving systems of congruences.\n5. Understand the concept of modular exponentiation and its applications in cryptography.\n6. Learn efficient algorithms for primality testing and factorization of integers.\n7. Understand the basics of elliptic curve cryptography and its applications in modern cryptography.\n8. Apply number-theoretic algorithms to solve real-world problems, such as generating large prime numbers and finding solutions to linear congruences.",
#  '\nThe main learning outcomes of the chapter on string matching are:\n\n1. Understand the concept of string matching and its importance in various applications.\n2. Identify different types of string matching problems, such as exact matching, approximate matching, and pattern matching.\n3. Learn about the naive string matching algorithm and its time complexity.\n4. Understand the concept of finite automata and how it can be used to improve string matching algorithms.\n5. Explore the Knuth-Morris-Pratt (KMP) algorithm and its advantages over the naive approach.\n6. Learn about the Boyer-Moore algorithm and its efficiency in searching for patterns in a text.\n7. Understand the concept of the Rabin-Karp algorithm and its use of hashing to improve string matching.\n8. Compare and contrast the different string matching algorithms and their time complexities.\n9. Apply the different string matching algorithms to real-world problems.\n10. Understand the limitations and possible errors of string matching algorithms.',
#  '\n1. Understand fundamental concepts and techniques in computational geometry, including geometric primitives, convex hulls, and intersection problems.\n2. Apply computational geometry algorithms and data structures to solve real-world problems.\n3. Analyze the time and space complexity of computational geometry algorithms.\n4. Evaluate the advantages and limitations of different computational geometry techniques.\n5. Recognize the importance of computational geometry in various fields, such as computer graphics, robotics, and geographic information systems.',
#  '\n1. Define NP-completeness and its significance in the field of algorithms.\n2. Understand the concept of polynomial-time reductions and how they are used to prove NP-completeness.\n3. Identify common NP-complete problems, such as the knapsack problem and the traveling salesman problem.\n4. Use reduction techniques to prove the NP-completeness of a problem.\n5. Apply approximation algorithms to solve NP-complete problems.\n6. Analyze the time complexity of algorithms for solving NP-complete problems.\n7. Understand the relationship between NP-completeness and the P vs. NP problem.\n8. Recognize the limitations and implications of NP-completeness in algorithm design and analysis.',
#  '\n1. Understand the concept of approximation algorithms and their role in solving optimization problems.\n2. Describe and analyze the performance guarantees and limitations of approximation algorithms.\n3. Apply approximation algorithms to solve various optimization problems, such as vertex cover, set cover, and traveling salesman problem.\n4. Analyze the complexity and running time of approximation algorithms and compare them to exact algorithms.\n5. Understand the trade-offs between the accuracy of an approximation algorithm and its running time.\n6. Identify and describe common techniques used in designing approximation algorithms, such as greedy algorithms and randomization.\n7. Evaluate the quality of an approximation algorithm based on its approximation ratio and worst-case input.']

# %%
learning_concepts = extractor.identify_learning_concepts(chapters = chapters)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 learning_concepts = extractor.identify_learning_concepts(chapters = chapters)
# ----> 2 learning_concepts.split('\n')
#
# AttributeError: 'list' object has no attribute 'split'
