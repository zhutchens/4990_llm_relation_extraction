# %%
from os import getenv
from dotenv import load_dotenv

load_dotenv()

link = getenv('dsa_6114')
from relation_algorithms.relation_extraction_functions import LLM_Relation_Extractor
extractor = LLM_Relation_Extractor(link = link)

# %%
chapters = ['The Role of Algorithms in Computing',
            'Getting Started',
            'Growth of Algoritmhs',
            'Divide-and-Conquer',
            'Probabilistic Analysis and Randomized Algorithms',
            'Heapsort',
            'Quicksort',
            'Sorting in Linear Time',
            'Medians and Order Statistics',
            'Elementary Data Structures',
            'Hash Tables',
            'Binary Search Trees',
            'Red-Black Trees',
            'Augmenting Data Structures',
            'Dynamic Programming',
            'Greedy Algorithms',
            'Amortized Analysis',
            'B-Trees',
            'Fibonacci Heaps',
            'van Emde Boas Trees',
            'Data Structure for Disjoint Sets',
            'Elementary Graph Algoritmhs',
            'Minimum Spanning Trees',
            'Single-Source Shortest Paths',
            'All-Pairs Shortest Paths',
            'Maximum Flow',
            'Multithreaded Algoritmhs',
            'Matrix Operations',
            'Linear Programming',
            'Polynomials and the FFT',
            'Number-Theoretic Algorithms',
            'String Matching',
            'Computational Geometry',
            'NP-Completeness',
            'Approximation Algorithms']
len(chapters)
# Out:
# 35

# %%
# learning_outcomes = extractor.identify_learning_outcomes(chapters = chapters)

# %%
# learning_concepts = extractor.identify_learning_concepts(chapters = chapters)

# %%
# main_concepts = extractor.identify_main_topics()
# main_concepts

# %%
# concept_outcome_dict = extractor.create_chapter_dict(outcomes = learning_outcomes, concepts = learning_concepts, chapters = chapters)

# %%
# chapter_associations = extractor.identify_associations(learning_dict = concept_outcome_dict)
# chapter_associations

# %%
# chapter_dependencies = extractor.identify_dependencies(chapter_names = chapters)
# chapter_dependencies

# %%
in_common_concepts, in_common_outcomes = extractor.find_commonalities(chapters = chapters)

# %%
in_common_concepts
# Out:
# {'The Role of Algorithms in Computing': ['1. Algorithm design and analysis',
#   '2. Data structures',
#   '3. Efficiency/complexity analysis',
#   '4. Divide and conquer approach',
#   '5. Greedy algorithms',
#   '6. Dynamic programming',
#   '7. Backtracking algorithms',
#   '8. Randomized algorithms',
#   '9. Parallel and distributed algorithms',
#   '10. Complexity theory',
#   '11. Problem solving strategies',
#   '12. Efficiency and optimization',
#   '13. Recursion',
#   '14. Definition and types of algorithms',
#   '15. Algorithm design techniques',
#   '16. Analysis of algorithm efficiency',
#   '17. Basic data structures',
#   '18. Sorting algorithms',
#   '19. Searching algorithms',
#   '20. Graph algorithms',
#   '21. Heuristics and approximation algorithms',
#   '22. Importance of algorithms in computing and solving real-world problems',
#   '23. Time and space complexity',
#   '24. Backtracking and branch-and-bound algorithms',
#   '25. Parallel algorithms',
# ...

# %%
in_common_outcomes
# Out:
# {'The Role of Algorithms in Computing': ['- Understanding the fundamental role of algorithms in computing',
#   '- Identifying different types of algorithms and their applications',
#   '- Analyzing the time and space complexity of algorithms and their impact on performance',
#   '- Applying appropriate algorithm design techniques',
#   '- Implementing and evaluating algorithms',
#   '- Solving real-world problems using algorithms',
#   '- Explaining the importance of data structures in algorithm design and their impact on efficiency',
#   '- Evaluating the tradeoffs between different algorithms for the same problem',
#   '- Discussing ethical considerations and limitations of algorithms in computing',
#   '- Understanding the fundamental concepts of algorithms and their role in computing',
#   '- Analyzing the efficiency and complexity of algorithms using BigO notation',
#   '- Applying various algorithm design techniques',
# ...

# %%
extractor.draw_hypergraph(common_concepts = in_common_concepts, common_outcomes = None)
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/hypernetx/classes/hypergraph.py:563: FutureWarning: This method or function will be deprecated in a future release. Public references to this method or function will be removed from the Hypergraph API in a future release.
#   self._nodes = self.E.restrict_to_levels([1])
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/hypernetx/classes/entityset.py:618: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   elements = self._dataframe.groupby(col1)[col2].unique().to_dict()
# ...

# %%
list(in_common_outcomes.keys())[0]
# Out:
# 'The Role of Algorithms in Computing'

# %%
extractor.draw_hypergraph(common_concepts = None, common_outcomes = in_common_outcomes)
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/hypernetx/classes/hypergraph.py:563: FutureWarning: This method or function will be deprecated in a future release. Public references to this method or function will be removed from the Hypergraph API in a future release.
#   self._nodes = self.E.restrict_to_levels([1])
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/hypernetx/classes/entityset.py:618: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   elements = self._dataframe.groupby(col1)[col2].unique().to_dict()
# ...
