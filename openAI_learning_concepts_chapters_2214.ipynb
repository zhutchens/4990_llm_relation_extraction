# %%
from langchain.llms import OpenAI
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader

# %%
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('team_token')
llm = OpenAI()

# %%
# using link to read textbook
link = os.getenv('dsa_2214')
chapters = {
    'Chapter 1': 'Data Structures and Algorithms',
    'Chapter 2': 'Mathematical Preliminaries',
    'Chapter 3': 'Algorithm Analysis',
    'Chapter 4': 'Lists, Stacks, and Queues',
    'Chapter 5': 'Binary Trees',
    'Chapter 6': 'Non-Binary Trees',
    'Chapter 7': 'Internal Sorting',
    'Chapter 8': 'File Processing and External Sorting',
    'Chapter 9': 'Searching',
    'Chapter 10': 'Indexing',
    'Chapter 11': 'Graphs',
    'Chapter 12': 'Lists and Arrays Revisited',
    'Chapter 13': 'Advanced Tree Structures',
    'Chapter 14': 'Analysis Techniques',
    'Chapter 15': 'Lower Bounds',
    'Chapter 16': 'Patterns of Algorithms',
    'Chapter 17': 'Limits to Computation'
}
learning_concepts = {}
for chapter in chapters:
    learning_concept = llm(f"Please identify the learning concept map for {chapter} in this textbook: {link}")
    learning_concepts[chapter] = learning_concept
# Out:
# /home/zhutchens/uncc/research/LLM/my_work/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(

# %%
for chapter, learning_concept in learning_concepts.items():
    print(f'CHAPTER: {chapter}')
    print(f'LEARNING CONCEPT: {learning_concept}')
# Out:
# CHAPTER: Chapter 1
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 1 in this textbook includes the following concepts:
#
# 1. Introduction to Data Structures and Algorithms
# - Definition of data structures and algorithms
# - Importance of data structures and algorithms in computer science
# - Examples of common data structures and algorithms
#
# 2. Basic Java Concepts
# - Basic syntax and structure of Java programming language
# - Data types and variables
# - Control structures (if/else, loops)
# - Methods and functions
#
# 3. Object-Oriented Programming
# - Overview of object-oriented programming
# - Classes and objects
# - Inheritance and polymorphism
# - Encapsulation and data hiding
#
# 4. Analysis of Algorithms
# - Importance of analyzing algorithms
# - Asymptotic notation (big-O, big-omega, big-theta)
# - Time and space complexity
#
# 5. Recursion
# - Definition of recursion
# - Recursive vs. iterative algorithms
# - Recursive solutions to common problems (factorial, Fibonacci sequence)
#
# 6. Abstract Data Types (ADTs)
# - Definition and characteristics of ADTs
# - Examples of common ADTs (stacks, queues, trees)
# - Implementation of ADTs in Java
#
# 7. Java Collections Framework
# - Overview of Java Collections Framework
# - List, set, and map interfaces
# - Common implementations of
# CHAPTER: Chapter 2
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 2 in this textbook is as follows:
#
# 1. Introduction to Algorithm Analysis
#     a. Definition of algorithm
#     b. Importance of algorithm analysis
#     c. Types of algorithm analysis
#
# 2. Mathematical Background
#     a. Asymptotic notation
#         i. Big-O
#         ii. Omega
#         iii. Theta
#     b. Growth of Functions
#         i. Constant function
#         ii. Logarithmic function
#         iii. Linear function
#         iv. Quadratic function
#         v. Exponential function
#
# 3. Order of Growth Classification
#     a. Constant
#     b. Logarithmic
#     c. Linear
#     d. Quadratic
#     e. Cubic
#     f. Exponential
#
# 4. Best, Worst, and Average Case Analysis
#     a. Definition of best, worst, and average case
#     b. Examples of each case
#     c. Analysis techniques
#         i. Counting operations
#         ii. Using mathematical formulas
#         iii. Using recurrence relations
#
# 5. Analyzing Control Statements
#     a. Sequential execution
#     b. Conditional execution
#     c. Looping execution
#     d. Recursive execution
#
# 6. Analysis of Loops
# CHAPTER: Chapter 3
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 3 in this textbook includes the following key concepts:
#
# 1. Arrays
# - Definition and characteristics
# - Array operations (accessing, inserting, deleting)
# - Array implementation in Java
# - Advantages and disadvantages of arrays
#
# 2. Linked Lists
# - Definition and characteristics
# - Types of linked lists (singly linked, doubly linked, circular)
# - Linked list operations (inserting, deleting, searching)
# - Linked list implementation in Java
# - Advantages and disadvantages of linked lists
#
# 3. Stacks
# - Definition and characteristics
# - Stack operations (push, pop, peek)
# - Stack implementation in Java
# - Applications of stacks (reversing strings, parenthesis matching)
# - Advantages and disadvantages of stacks
#
# 4. Queues
# - Definition and characteristics
# - Queue operations (enqueue, dequeue, peek)
# - Queue implementation in Java
# - Applications of queues (printing jobs, CPU scheduling)
# - Advantages and disadvantages of queues
#
# 5. Recursion
# - Definition and characteristics
# - Recursive vs. iterative solutions
# - Recursive algorithms (factorial, Fibonacci)
# - Recursion in data structures (binary trees, linked lists)
# - Advantages and disadvantages of recursion
#
# 6. Sorting Algorithms
# - Types of sorting algorithms (bubble
# CHAPTER: Chapter 4
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 4 of this textbook, titled "Recursion", can be represented as follows:
#
# 1. Introduction to Recursion
#     a. Definition of recursion
#     b. Examples of recursive algorithms
#     c. Advantages and disadvantages of recursion
#
# 2. Recursive Algorithms
#     a. Designing a recursive algorithm
#         i. Identifying base case
#         ii. Identifying recursive case
#         iii. General problem-solving strategies
#     b. Tracing a recursive algorithm
#         i. Visualizing the recursive calls
#         ii. Understanding the call stack
#     c. Time and space complexity of recursive algorithms
#
# 3. Recursive Data Structures
#     a. Definition of recursive data structures
#     b. Examples of recursive data structures
#     c. Recursive data structures vs. non-recursive data structures
#     d. Implementing recursive data structures
#
# 4. Types of Recursion
#     a. Linear recursion
#         i. Direct recursion
#         ii. Indirect recursion
#     b. Binary recursion
#     c. Multiple recursion
#
# 5. Tail Recursion
#     a. Definition of tail recursion
#     b. Advantages of tail recursion
#     c. Converting non-tail recursive algorithms to tail recursive algorithms
#
# 6.
# CHAPTER: Chapter 5
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 5, "Trees," in this textbook would include the following concepts:
#
# 1. Introduction to Trees
# - Definition of a tree
# - Properties of trees
# - Types of trees (binary trees, binary search trees, etc.)
#
# 2. Tree Traversal
# - Inorder traversal
# - Preorder traversal
# - Postorder traversal
# - Level-order traversal
#
# 3. Binary Trees
# - Definition of a binary tree
# - Binary tree representation
# - Binary tree operations (insertion, deletion, searching)
#
# 4. Binary Search Trees
# - Definition of a binary search tree
# - Properties of a binary search tree
# - Binary search tree operations (insertion, deletion, searching)
# - Time complexity of operations on a binary search tree
#
# 5. Balanced Binary Trees
# - Definition of a balanced binary tree
# - Types of balanced binary trees (AVL trees, Red-Black trees)
# - Balancing operations (rotations)
# - Advantages of using balanced binary trees
#
# 6. Heap Data Structure
# - Definition of a heap
# - Properties of a heap
# - Heap operations (insertion, deletion, finding minimum/maximum)
# - Heap applications (priority queues, heap sort)
#
# 7. Tree Applications
# - File system organization
# - Decision trees
# CHAPTER: Chapter 6
# LEARNING CONCEPT:
#
# Chapter 6 in this textbook covers the topic of "Trees." The learning concept map for this chapter would include the following main concepts:
#
# 1. Definition and properties of trees
# 2. Types of trees (binary, binary search, AVL)
# 3. Tree traversal algorithms (pre-order, in-order, post-order)
# 4. Binary tree representation (array, linked structure)
# 5. Binary search tree operations (insert, delete, search)
# 6. AVL tree balancing
# 7. Tree applications (expression trees, Huffman coding)
# 8. Tree implementation in Java (code examples)
#
# The concept map would also include sub-concepts and relationships between them, such as the fact that AVL trees are a type of balanced binary search tree, or that pre-order traversal can be used to create a prefix expression from an expression tree. It would also highlight the connections between different concepts, such as the use of binary trees in Huffman coding and their representation using linked structures in Java.
# CHAPTER: Chapter 7
# LEARNING CONCEPT:
#
# 1. Data Structures and Algorithms
#     A. Introduction to Data Structures and Algorithms
#     B. Importance of Data Structures and Algorithms
#     C. Basic Terminology
#     D. Complexity Analysis
#     E. Design Techniques
#         i. Divide and Conquer
#         ii. Greedy Algorithms
#         iii. Dynamic Programming
#     F. Implementing Algorithms
#         i. Arrays
#         ii. Linked Lists
#         iii. Stacks and Queues
#         iv. Hash Tables
#         v. Trees
#         vi. Heaps
#         vii. Graphs
# 2. Chapter 7: Trees
#     A. Introduction to Trees
#         i. Definition of a Tree
#         ii. Terminology
#     B. Binary Trees
#         i. Definition of Binary Trees
#         ii. Traversing Binary Trees
#             a. Pre-order Traversal
#             b. In-order Traversal
#             c. Post-order Traversal
#         iii. Binary Search Trees
#             a. Definition of BST
#             b. Searching in BST
#             c. Insertion and Deletion in BST
#         iv. Balanced Binary Trees
#             a. Definition of Balanced Trees
#             b. AVL Trees
#             c. Red-Black Trees
#
# CHAPTER: Chapter 8
# LEARNING CONCEPT:
#
# 1. Introduction to Trees
#     a. Definition of trees
#     b. Terminology (root, parent, child, leaf, etc.)
#     c. Examples of trees in real life
#
# 2. Binary Trees
#     a. Definition of binary trees
#     b. Properties of binary trees
#     c. Types of binary trees (full, complete, balanced, etc.)
#     d. Traversing binary trees (preorder, inorder, postorder)
#
# 3. Binary Search Trees (BSTs)
#     a. Definition of BSTs
#     b. Operations on BSTs (insertion, deletion, search)
#     c. Properties of BSTs (order, height, etc.)
#     d. Time complexity analysis for BST operations
#
# 4. AVL Trees
#     a. Definition of AVL trees
#     b. Balancing criteria (height difference)
#     c. Insertion and deletion in AVL trees
#     d. Time complexity analysis for AVL tree operations
#
# 5. Heap Trees
#     a. Definition of heap trees
#     b. Types of heap trees (max heap, min heap)
#     c. Heap operations (insertion, deletion, heapify)
#     d. Time complexity analysis for heap operations
#
# 6. Priority Queues
#     a. Definition
# CHAPTER: Chapter 9
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 9 may include the following key concepts:
#
# 1. Binary Search Trees
# - Definition and properties of binary search trees
# - Advantages of using binary search trees
# - Operations on binary search trees: insertion, deletion, searching
# - Implementing binary search trees in Java
# - Analysis of binary search tree operations
#
# 2. Balanced Binary Search Trees
# - Definition and properties of balanced binary search trees
# - Types of balanced binary search trees: AVL trees, red-black trees, B-trees
# - Operations on balanced binary search trees: insertion, deletion, searching
# - Implementing balanced binary search trees in Java
# - Analysis of balanced binary search tree operations
#
# 3. Tree Traversal Algorithms
# - Preorder, inorder, and postorder traversal
# - Uses of tree traversal algorithms
# - Implementing tree traversal algorithms in Java
# - Analysis of tree traversal algorithms
#
# 4. Heap Data Structure
# - Definition and properties of a heap
# - Types of heaps: max heap, min heap
# - Heap operations: insertion, deletion, heapify, extract min/max
# - Implementing heaps in Java
# - Analysis of heap operations
#
# 5. Heap Sort
# - Overview of the heap sort algorithm
# - Steps involved in heap sort
# - Analysis of
# CHAPTER: Chapter 10
# LEARNING CONCEPT:
#
# 1. Data Structures:
# - Definition and importance of data structures
# - Types of data structures: arrays, linked lists, stacks, queues, trees, graphs
# - Common operations on data structures: insertion, deletion, search, traversal
# - Comparison of different data structures
#
# 2. Abstract Data Types (ADTs):
# - Definition and characteristics of ADTs
# - Implementation of ADTs using data structures
# - Examples of ADTs: Set, Map, List
#
# 3. Algorithm Analysis:
# - Definition and importance of algorithm analysis
# - Time and space complexity of algorithms
# - Big-O notation
# - Best, average, and worst case analysis
# - Comparison of different algorithms
#
# 4. Sorting Algorithms:
# - Importance and need for sorting
# - Comparison of different sorting algorithms: bubble sort, selection sort, insertion sort, quicksort, mergesort, heapsort, radix sort
# - Analysis of sorting algorithms
#
# 5. Searching Algorithms:
# - Definition and importance of searching
# - Linear search and binary search
# - Comparison of different searching algorithms
# - Analysis of searching algorithms
#
# 6. Hashing:
# - Definition and importance of hashing
# - Hash functions and collision resolution techniques
# - Applications of hashing
#
# 7. Trees:
# - Definition and properties of trees
# - Types of trees: binary
# CHAPTER: Chapter 11
# LEARNING CONCEPT:
#
# Chapter 11 in this textbook covers the topic of Hash Tables. The learning concept map for this chapter may include the following key concepts:
#
# 1. Introduction to Hash Tables
# - Definition of Hash Tables
# - Advantages of using Hash Tables
# - Applications of Hash Tables
#
# 2. Hash Functions
# - Definition of Hash Functions
# - Types of Hash Functions (e.g. Division, Multiplication, Mid-square)
# - Properties of a good Hash Function (e.g. Uniformity, Speed, Collisions)
#
# 3. Collision Resolution
# - Definition of Collision
# - Separate Chaining
# - Open Addressing
# - Comparison of Collision Resolution methods
#
# 4. Analysis of Hash Tables
# - Hash Table Performance
# - Load Factor and its impact on performance
# - Worst-case and Average-case analysis
#
# 5. Implementing Hash Tables
# - Array-based Implementation
# - Linked List-based Implementation
# - Resizing and Rehashing techniques
#
# 6. Hash Table Variations
# - Double Hashing
# - Perfect Hashing
# - Cuckoo Hashing
#
# 7. Hash Tables in Java
# - Built-in Hash Table classes in Java (e.g. HashMap, HashTable)
# - Custom Hash Table implementation in Java
#
# 8. Applications of Hash Tables
# - Searching and Retrieving data
# -
# CHAPTER: Chapter 12
# LEARNING CONCEPT:
#
# Unfortunately, the textbook provided does not have a Chapter 12. It only has up to Chapter 7. Can you please provide the correct textbook or chapter number for me to accurately create the learning concept map? Thank you.
#
# CHAPTER: Chapter 13
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 13, "Red-Black Trees", in this textbook may include the following key concepts and their relationships:
#
# 1. Binary Search Trees
#     - Definition and properties
#     - Operations (insertion, deletion, searching)
#     - Time complexity analysis
#
# 2. Balanced Search Trees
#     - Definition and importance
#     - Types (AVL trees, red-black trees, etc.)
#     - Benefits and drawbacks
#
# 3. Red-Black Trees
#     - Definition and properties
#     - Insertion and deletion operations
#     - Balancing rules and rotations
#     - Time complexity analysis
#
# 4. Red-Black Tree Implementation
#     - Node structure and attributes
#     - Color-coding scheme
#     - Algorithms for insertion and deletion
#     - Code examples and pseudocode
#
# 5. Applications of Red-Black Trees
#     - Common use cases (e.g. Java's TreeMap class)
#     - Advantages over other balanced trees
#     - Real-world examples and performance comparisons
#
# 6. Red-Black Trees vs AVL Trees
#     - Similarities and differences
#     - Comparison of balancing rules and time complexity
#     - When to use each type of tree
#
# 7. Red-Black Trees vs Hash Tables
#     - Comparison of
# CHAPTER: Chapter 14
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 14 in this textbook includes the following concepts:
#
# 1. Introduction to Graphs
# - Definition of graphs
# - Terminology (vertices, edges, degree, etc.)
# - Types of graphs (undirected, directed, weighted, etc.)
#
# 2. Graph Representations
# - Adjacency matrix
# - Adjacency list
# - Comparison between the two representations
# - Space and time complexities
#
# 3. Graph Traversals
# - Depth-first search (DFS)
# - Breadth-first search (BFS)
# - Implementation using stacks and queues
# - Applications of graph traversals
#
# 4. Shortest Paths
# - Single-source shortest path problem
# - Dijkstra's algorithm
# - Bellman-Ford algorithm
# - Comparison between the two algorithms
#
# 5. Minimum Spanning Trees
# - Definition and properties
# - Kruskal's algorithm
# - Prim's algorithm
# - Comparison between the two algorithms
#
# 6. Topological Sorting
# - Definition and applications
# - Algorithm for topological sorting
# - Implementation using depth-first search
#
# 7. Network Flow Problems
# - Flow networks
# - Maximum flow problem
# - Ford-Fulkerson algorithm
# - Edmonds-Karp algorithm
# - Applications of network flow problems
#
# 8. Introduction to NP-hard Problems
# - Definition
# CHAPTER: Chapter 15
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 15 in this textbook includes the following topics:
#
# 1. Introduction to Graphs
#     - Definition of a graph
#     - Types of graphs (directed vs. undirected, weighted vs. unweighted)
#     - Representations of graphs (adjacency matrix, adjacency list)
#
# 2. Graph Traversal
#     - Depth-first search (DFS)
#         - Recursive implementation
#         - Iterative implementation using a stack
#     - Breadth-first search (BFS)
#         - Implementation using a queue
#
# 3. Spanning Trees
#     - Definition of a spanning tree
#     - Minimum spanning tree (MST)
#         - Prim's algorithm
#         - Kruskal's algorithm
#
# 4. Shortest Paths
#     - Single-source shortest path problem
#         - Dijkstra's algorithm
#         - Bellman-Ford algorithm
#         - Comparison of algorithms
#     - All-pairs shortest path problem
#         - Floyd-Warshall algorithm
#         - Johnson's algorithm
#
# 5. Topological Sorting
#     - Definition of a topological sort
#     - Topological sorting algorithm
#
# 6. Directed Acyclic Graphs (DAGs)
#     - Definition and properties of DAGs
#     - Applications of DAGs
#     -
# CHAPTER: Chapter 16
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 16 in this textbook is as follows:
#
# I. Introduction to Dynamic Programming
#     A. Definition and overview of Dynamic Programming
#     B. Steps involved in solving a problem using Dynamic Programming
#     C. Advantages and limitations of Dynamic Programming
#
# II. Memoization
#     A. Definition and explanation of Memoization
#     B. Implementation of Memoization in solving problems
#     C. Time and space complexity analysis of Memoization
#
# III. Tabulation
#     A. Definition and explanation of Tabulation
#     B. Implementation of Tabulation in solving problems
#     C. Time and space complexity analysis of Tabulation
#
# IV. Applications of Dynamic Programming
#     A. Knapsack problem
#         1. Definition and explanation of Knapsack problem
#         2. Solving Knapsack problem using Dynamic Programming
#     B. Longest Common Subsequence problem
#         1. Definition and explanation of Longest Common Subsequence problem
#         2. Solving Longest Common Subsequence problem using Dynamic Programming
#     C. Matrix Chain Multiplication problem
#         1. Definition and explanation of Matrix Chain Multiplication problem
#         2. Solving Matrix Chain Multiplication problem using Dynamic Programming
#
# V.
# CHAPTER: Chapter 17
# LEARNING CONCEPT:
#
# The learning concept map for Chapter 17, "Priority Queues and Heaps," in the textbook "Data Structures and Algorithm Analysis in Java" by Clifford A. Shaffer is as follows:
#
# 1. Priority Queues
#     a. Definition
#     b. Basic Operations
#         i. Insert
#         ii. DeleteMin
#         iii. FindMin
#     c. Applications
#         i. Dijkstra's Algorithm
#         ii. Huffman Coding
#         iii. Event-driven Simulation
#     d. Implementation
#         i. Array-based
#         ii. Linked List-based
#         iii. Binary Heap
#
# 2. Binary Heap
#     a. Definition
#     b. Properties
#         i. Complete Binary Tree
#         ii. Heap Order Property
#     c. Operations
#         i. BuildHeap
#         ii. PercolateUp
#         iii. PercolateDown
#     d. Implementation
#         i. Array-based
#         ii. Linked List-based
#
# 3. Heap Sort
#     a. Overview
#     b. Algorithm
#     c. Analysis
#         i. Time Complexity
#         ii. Space Complexity
#     d. Comparison with Other Sorting Algorithms
#
# 4. Priority Queue Applications
#     a. Dijkstra's Algorithm
#         i.
